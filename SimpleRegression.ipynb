# %% [markdown]
# Import the relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Generate random input data to train on

# %%
observations = 1000
# We will work with two variables as inputs. You can think about them as x1 and x2 
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(-10, 10, (observations,1))
inputs = np.column_stack((xs,zs))
print (inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# Generate the targets we will aim at

# %%
# We add a small random noise to the function i.e. f(x,z) = 2x - 3z + 5 + <small noise>
noise = np.random.uniform(-1, 1, (observations,1))
# Produce the targets according to the f(x,z) = 2x - 3z + 5 + noise definition.
targets = 2*xs - 3*zs + 5 + noise
print (targets.shape)
print(xs.shape)
print(zs.shape)
# Out:
# (1000, 1)
# (1000, 1)
# (1000, 1)

# %% [markdown]
# Plot the training data

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(xs, zs, targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
ax.view_init(azim=100)
plt.show()

# %% [markdown]
# Initialize variables

# %%
init_range = 0.1
weights = np.random.uniform(low=-init_range, high=init_range, size=(2, 1))
biases = np.random.uniform(low=-init_range, high=init_range, size=1)
print (weights)
print (biases)
# Out:
# [[-0.0354764 ]
#  [ 0.09052009]]
# [-0.05672841]

# %% [markdown]
# Set a learning rate

# %%
learning_rate = 0.2

# %% [markdown]
# Train the model

# %%
for i in range (100):
    outputs = np.dot(inputs,weights) + biases
    deltas = outputs - targets
    loss = np.sum(deltas ** 2) / 2 / observations
    print (loss)
    deltas_scaled = deltas / observations
    # Finally, we must apply the gradient descent update rules.
    weights = weights - learning_rate * np.dot(inputs.T,deltas_scaled)
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# 235.1147643948412
# 7109.796373205414
# 227390.20910115173
# 7286462.2438624855
# 233669234.19282436
# 7499181729.950865
# 240852206792.8172
# 7741202279419.742
# 248990874883735.44
# 8014408203506288.0
# 2.5814748193775875e+17
# 8.320851374947244e+18
# 2.683896525219553e+20
# 8.662760109395159e+21
# 2.797907995149603e+23
# 9.042552626227429e+24
# 2.9243056659523397e+26
# 9.462851592078785e+27
# 3.0639530623653533e+29
# 9.926499830440412e+30
# 3.2177859599895392e+32
# 1.043657728896481e+34
# 3.386817961260836e+35
# 1.0996419363380474e+37
# 3.572146516975241e+38
# 1.1609636684757983e+40
# 3.7749594284337865e+41
# 1.228013648532748e+43
# 3.996541868052313e+44
# 1.3012145667173036e+46
# 4.238283959278202e+47
# 1.381023570797398e+49
# 4.50168895989073e+50
# 1.467934954859056e+52
# 4.788382096251669e+53
# 1.562483061875173e+55
# 5.100120099838161e+56
# 1.6652454169475128e+58
# 5.438801501453343e+59
# 1.7768461094194723e+61
# 5.806477742894509e+62
# 1.8979594434974915e+64
# 6.205365170589422e+65
# 2.0293138785727878e+67
# 6.637857980815667e+68
# 2.1716962821121775e+70
# 7.106542191627048e+71
# 2.3259565197959104e+73
# 7.614210722553336e+74
# 2.4930124095329006e+76
# 8.1638796695545e+77
# 2.673855068090453e+79
# 8.758805869628825e+80
# 2.869554681348773e+82
# 9.40250585694403e+83
# 3.08126673164352e+85
# 1.009877632041586e+87
# 3.3102387183064124e+88
# 1.0851716181354586e+90
# 3.557817410370013e+91
# 1.1665750419180962e+93
# 3.8254566734846896e+94
# 1.254565578333732e+96
# 4.114725916421075e+97
# 1.3496588540442458e+99
# 4.427319206119958e+100
# 1.4524114417527394e+102
# 4.765065104123239e+103
# 1.5634240914907506e+105
# 5.129937281398255e+106
# 1.683345217597189e+108
# 5.524065973075555e+109
# 1.8128746615981034e+111
# 5.949750339486002e+112
# 1.952767752794294e+114
# 6.4094718051316215e+115
# 2.1038396900885297e+117
# 6.905908452890161e+118
# 2.2669702704445124e+120
# 7.4419505568649535e+121
# 2.443108991377873e+123
# 8.02071734388761e+124
# 2.6332805570459236e+126
# 8.645575080798631e+127
# 2.838590819841028e+129
# 9.32015659230973e+130
# 3.060233191914781e+132
# 1.004838232254008e+134
# 3.299495563782915e+135
# 1.0834483062259535e+137
# 3.557767770097877e+138
# 1.1683024473521961e+140
# 3.836549645845816e+141
# 1.2598933553783763e+143
# 4.137459719645046e+144
# 1.3587527192837173e+146
# 4.462244594513731e+147
# 1.4654542988012726e+149
# 4.81278907045677e+150
# 1.5806172496186442e+152

# %% [markdown]
# Print weights and biases and see if we have worked correctly.

# %%
print (weights, biases)
# Out:
# [[-1.68865297e+76]
#  [ 4.82922674e+75]] [1.47363629e+74]

# %% [markdown]
# Plot last outputs vs targets

# %%
plt.plot(outputs,targets)
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
